# %%
### 1. Mount Google Drive ###

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python312/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
### 2. Prepare data ###

# !scp '/content/gdrive/My Drive/data.zip' '/content/data.zip'


# !unzip '/content/data.zip' -d '/content/'
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python312/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
### 3. Install Ultralytics ###

# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 9.7 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n-cls.pt")  # load a pretained model

# Use the model
results = model.train(data='/content/data/', epochs=6)  # train the model
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 61.1MB/s]
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
import numpy as np
# Load the trained image classification model
model = YOLO('runs/classify/train/weights/best.pt')

# %%
# Perform image classification on the new image
#results = model('normal.jpg')

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/anomalydetection'
